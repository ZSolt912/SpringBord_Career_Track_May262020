# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# upload the data
url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"
#read the data from an excel file 
properties=pd.read_excel(url_LondonHousePrices,sheet_name='Average price',index_col=None)
print(properties.head())
properties.info() # examine the data
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
# Switch columns and rows
properties=properties.transpose()

# %%
print(properties.head())
# Out:
#         Date City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH EAST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000001
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    42076.4
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...      42572
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    42369.7
# 4    72965.6    81124.4     120098      68610    82188.9  ...    42095.8
#
#   NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
print(properties.tail())
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
properties.reset_index()
# Out:
#      index Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        0        NaT      E09000001          E09000002  E09000003  E09000004
# 1        1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2        2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3        3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4        4 1995-04-01        77101.2            53133.5    90762.9    64277.7
# ..     ...        ...            ...                ...        ...        ...
# 299    299 2019-11-01         776894             306390     522639     333657
# 300    300 2019-12-01         737275             301283     519306     336302
# 301    301 2020-01-01         757377             304187     520115     334430
# 302    302 2020-02-01         765416             304719     520966     334845
# 303    303 2020-03-01         792583             327136     532569     331679
#
# ...

# %%
properties_z=properties.transpose()
print (properties_z.head())
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
properties.reset_index()
# Out:
#      index Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        0        NaT      E09000001          E09000002  E09000003  E09000004
# 1        1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2        2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3        3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4        4 1995-04-01        77101.2            53133.5    90762.9    64277.7
# ..     ...        ...            ...                ...        ...        ...
# 299    299 2019-11-01         776894             306390     522639     333657
# 300    300 2019-12-01         737275             301283     519306     336302
# 301    301 2020-01-01         757377             304187     520115     334430
# 302    302 2020-02-01         765416             304719     520966     334845
# 303    303 2020-03-01         792583             327136     532569     331679
#
# ...

# %%
properties.rename(columns={'Unnamed: 0':'Date'}, inplace=True) 
print (properties.head())
# Out:
#         Date City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
#remove Unnamed cols
properties=properties.dropna(axis=1,how='all')
print (properties.head())
# Out:
#         Date City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH EAST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000001
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    42076.4
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...      42572
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    42369.7
# 4    72965.6    81124.4     120098      68610    82188.9  ...    42095.8
#
#   NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
# to pullout the main 33 districts from the dataframe

properties33D=properties.iloc[1:,0:34] 

print(properties33D.head())
# Out:
#         Date City of London Barking & Dagenham   Barnet   Bexley    Brent  \
# 1 1995-01-01          91449            50460.2  93284.5  64958.1  71306.6
# 2 1995-02-01        82202.8            51085.8  93190.2  64787.9  72022.3
# 3 1995-03-01        79120.7              51269  92247.5  64367.5  72015.8
# 4 1995-04-01        77101.2            53133.5  90762.9  64277.7  72965.6
# 5 1995-05-01        84409.1            53042.2    90258  63997.1    73704
#
#    Bromley  Camden  Croydon   Ealing  ...   Merton   Newham Redbridge  \
# 1  81671.5  120933  69158.2  79885.9  ...  82070.6  53539.3   72189.6
# 2  81657.6  119509  68951.1  80897.1  ...  79982.7  53153.9   72141.6
# 3  81449.3  120282  68712.4  81379.9  ...  80661.7  53458.3   72501.4
# 4  81124.4  120098    68610  82188.9  ...  79990.5  54479.8   72228.6
# 5  81542.6  119929  68844.9  82077.1  ...    80874    55804   72366.6
#
#   Richmond upon Thames Southwark   Sutton Tower Hamlets Waltham Forest  \
# ...

# %%
# Remove City of London from columns
properties32Dfinal=properties33D.drop(properties33D.columns[1], axis =1)
print(properties32Dfinal)
# Out:
#           Date Barking & Dagenham   Barnet   Bexley    Brent  Bromley  Camden  \
# 1   1995-01-01            50460.2  93284.5  64958.1  71306.6  81671.5  120933
# 2   1995-02-01            51085.8  93190.2  64787.9  72022.3  81657.6  119509
# 3   1995-03-01              51269  92247.5  64367.5  72015.8  81449.3  120282
# 4   1995-04-01            53133.5  90762.9  64277.7  72965.6  81124.4  120098
# 5   1995-05-01            53042.2    90258  63997.1    73704  81542.6  119929
# ..         ...                ...      ...      ...      ...      ...     ...
# 299 2019-11-01             306390   522639   333657   432188   436080  825336
# 300 2019-12-01             301283   519306   336302   427126   438682  807124
# 301 2020-01-01             304187   520115   334430   424663   435337  816906
# 302 2020-02-01             304719   520966   334845   471574   436544  818558
# 303 2020-03-01             327136   532569   331679   446966   430033  881096
#
# ...

# %%
properties32Dfinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 1 to 303
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  303 non-null    datetime64[ns]
#  1   Barking & Dagenham    303 non-null    object
#  2   Barnet                303 non-null    object
#  3   Bexley                303 non-null    object
#  4   Brent                 303 non-null    object
#  5   Bromley               303 non-null    object
#  6   Camden                303 non-null    object
#  7   Croydon               303 non-null    object
#  8   Ealing                303 non-null    object
#  9   Enfield               303 non-null    object
#  10  Greenwich             303 non-null    object
#  11  Hackney               303 non-null    object
#  12  Hammersmith & Fulham  303 non-null    object
#  13  Haringey              303 non-null    object
# ...

# %%
# set Date as Index
properties32Dfinal.set_index("Date") # final Data frame after cleaning, filtering and reindexing
# Out:
#            Barking & Dagenham   Barnet   Bexley    Brent  Bromley  Camden  \
# Date
# 1995-01-01            50460.2  93284.5  64958.1  71306.6  81671.5  120933
# 1995-02-01            51085.8  93190.2  64787.9  72022.3  81657.6  119509
# 1995-03-01              51269  92247.5  64367.5  72015.8  81449.3  120282
# 1995-04-01            53133.5  90762.9  64277.7  72965.6  81124.4  120098
# 1995-05-01            53042.2    90258  63997.1    73704  81542.6  119929
# ...                       ...      ...      ...      ...      ...     ...
# 2019-11-01             306390   522639   333657   432188   436080  825336
# 2019-12-01             301283   519306   336302   427126   438682  807124
# 2020-01-01             304187   520115   334430   424663   435337  816906
# 2020-02-01             304719   520966   334845   471574   436544  818558
# 2020-03-01             327136   532569   331679   446966   430033  881096
#
#             Croydon   Ealing  Enfield Greenwich  ...   Merton   Newham  \
# ...

# %%
#creating a list of Boroughs and removing "Date"

London_Borough=list (properties32Dfinal.columns.values)
del London_Borough[0]
print(London_Borough)
# Out:
# ['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster']

# %%
# visualize two distrcits growth
plot= properties32Dfinal.plot(x='Date',y=['Haringey', 'Kingston upon Thames'] )
plot.set_ylabel('Ave Price')
# Out:
# Text(0, 0.5, 'Ave Price')

# %%
# visualize all distrcits growth

plot= properties32Dfinal.plot(x='Date',y=London_Borough)
plot.set_ylabel('Ave Price')
# Out:
# Text(0, 0.5, 'Ave Price')

# %%
# Changing the data type to float
cols = properties32Dfinal.select_dtypes(exclude=['datetime']).columns

properties32Dfinal[cols] = properties32Dfinal[cols].apply(pd.to_numeric, downcast='float', errors='coerce')

properties32Dfinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 1 to 303
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  303 non-null    datetime64[ns]
#  1   Barking & Dagenham    303 non-null    float32
#  2   Barnet                303 non-null    float32
#  3   Bexley                303 non-null    float32
#  4   Brent                 303 non-null    float32
#  5   Bromley               303 non-null    float32
#  6   Camden                303 non-null    float32
#  7   Croydon               303 non-null    float32
#  8   Ealing                303 non-null    float32
#  9   Enfield               303 non-null    float32
#  10  Greenwich             303 non-null    float32
#  11  Hackney               303 non-null    float32
#  12  Hammersmith & Fulham  303 non-null    float32
#  13  Haringey              303 non-null    float32
# ...

# %%
#seperate the Year from the Date
# didnot need this just to try this command
year=properties32Dfinal['Date'].dt.year
print (year)
# Out:
# 1      1995
# 2      1995
# 3      1995
# 4      1995
# 5      1995
#        ...
# 299    2019
# 300    2019
# 301    2020
# 302    2020
# 303    2020
# Name: Date, Length: 303, dtype: int64

# %%
# add year to data frame
properties32Dfinal['Year'] = pd.DatetimeIndex(properties32Dfinal['Date']).year

print (properties32Dfinal.tail())
# Out:
#           Date  Barking & Dagenham       Barnet        Bexley         Brent  \
# 299 2019-11-01        306390.25000  522639.0000  333657.46875  432187.68750
# 300 2019-12-01        301283.43750  519306.2500  336301.87500  427126.34375
# 301 2020-01-01        304187.46875  520115.3750  334430.37500  424662.71875
# 302 2020-02-01        304719.31250  520965.8125  334845.25000  471573.65625
# 303 2020-03-01        327135.65625  532568.9375  331679.40625  446966.28125
#
#           Bromley       Camden       Croydon        Ealing       Enfield  ...  \
# 299  436079.62500  825336.3125  367584.56250  475491.59375  393255.09375  ...
# 300  438681.81250  807124.1875  369567.87500  469662.03125  400182.40625  ...
# 301  435337.28125  816905.7500  371917.93750  467351.37500  390574.90625  ...
# 302  436543.84375  818558.3750  371685.75000  467962.56250  391100.28125  ...
# 303  430032.81250  881095.9375  358355.78125  454027.34375  386000.09375  ...
#
# ...

# %%
# Change the Index to Year
properties32Dfinal.set_index('Year', drop=True, append=False, inplace=False, verify_integrity=False)
# Out:
#            Date  Barking & Dagenham         Barnet         Bexley  \
# Year
# 1995 1995-01-01        50460.226562   93284.515625   64958.089844
# 1995 1995-02-01        51085.781250   93190.171875   64787.921875
# 1995 1995-03-01        51268.968750   92247.523438   64367.492188
# 1995 1995-04-01        53133.503906   90762.875000   64277.667969
# 1995 1995-05-01        53042.250000   90258.000000   63997.136719
# ...         ...                 ...            ...            ...
# 2019 2019-11-01       306390.250000  522639.000000  333657.468750
# 2019 2019-12-01       301283.437500  519306.250000  336301.875000
# 2020 2020-01-01       304187.468750  520115.375000  334430.375000
# 2020 2020-02-01       304719.312500  520965.812500  334845.250000
# 2020 2020-03-01       327135.656250  532568.937500  331679.406250
#
#               Brent        Bromley         Camden        Croydon  \
# Year
# 1995   71306.570312   81671.476562  120932.890625   69158.164062
# ...

# %%
mean1995=properties32Dfinal[London_Borough].loc[properties32Dfinal['Date'].dt.year==1995].mean(axis=0)
print (mean1995)
# Out:
# Barking & Dagenham       51817.968750
# Barnet                   91792.539062
# Bexley                   64291.531250
# Brent                    73029.851562
# Bromley                  81967.320312
# Camden                  120367.429688
# Croydon                  68923.335938
# Ealing                   81218.671875
# Enfield                  71984.226562
# Greenwich                63389.785156
# Hackney                  66024.476562
# Hammersmith & Fulham    123238.000000
# Haringey                 80078.492188
# Harrow                   83519.492188
# Havering                 68281.007812
# Hillingdon               73755.757812
# Hounslow                 72941.171875
# Islington                95555.062500
# Kensington & Chelsea    192857.250000
# Kingston upon Thames     82838.992188
# Lambeth                  68105.695312
# Lewisham                 58881.761719
# Merton                   80500.765625
# Newham                   54574.222656
# Redbridge                72580.492188
# ...

# %%
# creating a annual average foreach year 
mean2018=properties32Dfinal[London_Borough].loc[properties32Dfinal['Date'].dt.year==2018].mean(axis=0)
print(mean2018)
# Out:
# Barking & Dagenham      2.951967e+05
# Barnet                  5.332666e+05
# Bexley                  3.426036e+05
# Brent                   4.928453e+05
# Bromley                 4.434100e+05
# Camden                  8.424103e+05
# Croydon                 3.702985e+05
# Ealing                  4.800506e+05
# Enfield                 3.966317e+05
# Greenwich               3.883443e+05
# Hackney                 5.446405e+05
# Hammersmith & Fulham    7.255253e+05
# Haringey                5.515606e+05
# Harrow                  4.659074e+05
# Havering                3.702488e+05
# Hillingdon              4.102661e+05
# Hounslow                3.966312e+05
# Islington               6.498241e+05
# Kensington & Chelsea    1.363880e+06
# Kingston upon Thames    4.970910e+05
# Lambeth                 5.115364e+05
# Lewisham                4.116290e+05
# Merton                  5.122939e+05
# Newham                  3.590225e+05
# Redbridge               4.225910e+05
# ...

# %%
#pct growth calculation
growth=(mean2018-mean1995)*100/mean1995
print(growth)
# Out:
# Barking & Dagenham      469.680176
# Barnet                  480.947632
# Bexley                  432.890686
# Brent                   574.854675
# Bromley                 440.959503
# Camden                  599.865662
# Croydon                 437.261444
# Ealing                  491.059387
# Enfield                 450.998108
# Greenwich               512.629211
# Hackney                 724.906982
# Hammersmith & Fulham    488.718842
# Haringey                588.774963
# Harrow                  457.842712
# Havering                442.242676
# Hillingdon              456.249603
# Hounslow                443.768646
# Islington               580.051941
# Kensington & Chelsea    607.196655
# Kingston upon Thames    500.068848
# Lambeth                 651.091980
# Lewisham                599.077271
# Merton                  536.383850
# Newham                  557.860962
# Redbridge               482.237732
# Richmond upon Thames    493.913879
# Southwark               684.679443
# ...

# %%
growthofboroughs={'Mean_1995': mean1995, 'Mean_2018': mean2018,'Growth':growth}
growthdf = pd.DataFrame(growthofboroughs)

print(growthdf)
# Out:
#                           Mean_1995     Mean_2018      Growth
# Barking & Dagenham     51817.968750  2.951967e+05  469.680176
# Barnet                 91792.539062  5.332666e+05  480.947632
# Bexley                 64291.531250  3.426036e+05  432.890686
# Brent                  73029.851562  4.928453e+05  574.854675
# Bromley                81967.320312  4.434100e+05  440.959503
# Camden                120367.429688  8.424103e+05  599.865662
# Croydon                68923.335938  3.702985e+05  437.261444
# Ealing                 81218.671875  4.800506e+05  491.059387
# Enfield                71984.226562  3.966317e+05  450.998108
# Greenwich              63389.785156  3.883443e+05  512.629211
# Hackney                66024.476562  5.446405e+05  724.906982
# Hammersmith & Fulham  123238.000000  7.255253e+05  488.718842
# Haringey               80078.492188  5.515606e+05  588.774963
# Harrow                 83519.492188  4.659074e+05  457.842712
# ...

# %%
growthdf.reset_index()
# Out:
#                    index      Mean_1995     Mean_2018      Growth
# 0     Barking & Dagenham   51817.968750  2.951967e+05  469.680176
# 1                 Barnet   91792.539062  5.332666e+05  480.947632
# 2                 Bexley   64291.531250  3.426036e+05  432.890686
# 3                  Brent   73029.851562  4.928453e+05  574.854675
# 4                Bromley   81967.320312  4.434100e+05  440.959503
# 5                 Camden  120367.429688  8.424103e+05  599.865662
# 6                Croydon   68923.335938  3.702985e+05  437.261444
# 7                 Ealing   81218.671875  4.800506e+05  491.059387
# 8                Enfield   71984.226562  3.966317e+05  450.998108
# 9              Greenwich   63389.785156  3.883443e+05  512.629211
# 10               Hackney   66024.476562  5.446405e+05  724.906982
# 11  Hammersmith & Fulham  123238.000000  7.255253e+05  488.718842
# 12              Haringey   80078.492188  5.515606e+05  588.774963
# ...

# %%
print (growthdf.index.name)
# Out:
# None

# %%
growthdf.index.names = ['Boroughs']
print (growthdf)
# Out:
#                           Mean_1995     Mean_2018      Growth
# Boroughs
# Barking & Dagenham     51817.968750  2.951967e+05  469.680176
# Barnet                 91792.539062  5.332666e+05  480.947632
# Bexley                 64291.531250  3.426036e+05  432.890686
# Brent                  73029.851562  4.928453e+05  574.854675
# Bromley                81967.320312  4.434100e+05  440.959503
# Camden                120367.429688  8.424103e+05  599.865662
# Croydon                68923.335938  3.702985e+05  437.261444
# Ealing                 81218.671875  4.800506e+05  491.059387
# Enfield                71984.226562  3.966317e+05  450.998108
# Greenwich              63389.785156  3.883443e+05  512.629211
# Hackney                66024.476562  5.446405e+05  724.906982
# Hammersmith & Fulham  123238.000000  7.255253e+05  488.718842
# Haringey               80078.492188  5.515606e+05  588.774963
# Harrow                 83519.492188  4.659074e+05  457.842712
# ...

# %%
growthdf['Growth'].max()
# Out:
# 724.906982421875

# %%
growthdf[growthdf['Growth'] == growthdf['Growth'].max()].index[0]
# Out:
# 'Hackney'

# %%
plot= properties32Dfinal.plot(x='Date',y='Hackney')
plot.set_ylabel('Ave Price')
# Out:
# Text(0, 0.5, 'Ave Price')

# %%
growthdf.nlargest(5, ['Growth'])
# Out:
#                     Mean_1995     Mean_2018      Growth
# Boroughs
# Hackney          66024.476562  5.446405e+05  724.906982
# Southwark        64260.050781  5.042354e+05  684.679443
# Westminster     133689.234375  1.020025e+06  662.982361
# Lambeth          68105.695312  5.115364e+05  651.091980
# Waltham Forest   61279.972656  4.408594e+05  619.418335

# %%
plot= properties32Dfinal.plot(x='Date',y=['Hackney','Southwark','Westminster','Lambeth','Waltham Forest'])
plot.set_ylabel('Ave Price')
# Out:
# Text(0, 0.5, 'Ave Price')
